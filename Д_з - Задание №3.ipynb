# %% [markdown]
# Тема 2. Множество

# %% [markdown]
# 1.Даны три множества a,b и с. Необходимо выполнить все изученные виды бинарных операций над всеми комбинациями множеств.

# %%
a = {2, 6, 5, 7, "семь", "четыре"}
b = {6, 2, 4, 8, 12, "два", "один"}
c = {4, 6, 8, 9, 23, 'триста'}

# %%
# объединение (логическое И)
print(f'Пересечение a & b = {a & b}')
print(f'Пересечение a & c = {a & c}')
print(f'Пересечение b & c = {b & c}')
print(f'Пересечение a & b & c = {a & b & c}')
# Out:
# Пересечение a & b = {2, 6}
# Пересечение a & c = {6}
# Пересечение b & c = {8, 4, 6}
# Пересечение a & b & c = {6}

# %%
# объединение (логическое ИЛИ)
print(f'Объединение a | b = {a | b}')
print(f'Объединение a | c = {a | c}')
print(f'Объединение b | c = {b | c}')
print(f'Объединение a | b | c = {a | b | c}')
# Out:
# Объединение a | b = {2, 4, 5, 6, 7, 8, 'два', 12, 'один', 'четыре', 'семь'}
# Объединение a | c = {2, 4, 5, 6, 7, 8, 9, 'четыре', 'семь', 23, 'триста'}
# Объединение b | c = {2, 4, 6, 8, 9, 'два', 12, 'один', 23, 'триста'}
# Объединение a | b | c = {2, 4, 5, 6, 7, 8, 9, 'два', 12, 'один', 'четыре', 'семь', 23, 'триста'}

# %%
# разность
print(f'Разность a - b = {a - b}')
print(f'Разность a - c = {a - c}')
print(f'Разность b - c = {b - c}')
print(f'Разность b - a = {b - a}')
print(f'Разность c - a = {c - a}')
print(f'Разность c - b = {c - b}')
print(f'Разность a - b - c = {a - b - c}')
print(f'Разность b - a - c = {b - a - c}')
print(f'Разность c - a - c = {c - a - b}')
# Out:
# Разность a - b = {'четыре', 'семь', 5, 7}
# Разность a - c = {2, 5, 7, 'четыре', 'семь'}
# Разность b - c = {2, 12, 'один', 'два'}
# Разность b - a = {4, 8, 'два', 12, 'один'}
# Разность c - a = {'триста', 4, 8, 9, 23}
# Разность c - b = {9, 23, 'триста'}
# Разность a - b - c = {'семь', 7, 5, 'четыре'}
# Разность b - a - c = {'два', 12, 'один'}
# Разность c - a - c = {9, 23, 'триста'}

# %%
# симметрическая разность
print(f'Симметрическая разность a ^ b = {a ^ b}')
print(f'Симметрическая разность a ^ c = {a ^ c}')
print(f'Симметрическая разность b ^ c = {b ^ c}')
print(f'Симметрическая разность a ^ b ^ c = {a ^ b ^ c}')
# Out:
# Симметрическая разность a ^ b = {4, 5, 7, 8, 12, 'один', 'четыре', 'семь', 'два'}
# Симметрическая разность a ^ c = {2, 4, 5, 7, 8, 9, 'четыре', 'семь', 'триста', 23}
# Симметрическая разность b ^ c = {2, 9, 'два', 12, 'один', 23, 'триста'}
# Симметрическая разность a ^ b ^ c = {5, 6, 7, 9, 'два', 12, 'один', 'четыре', 'семь', 23, 'триста'}

# %%
# декартово произведение
from itertools import product

print(f'Декартово произведение a X b = ')
print(list(product(a, b))), print(len(a), end=' * '),  print(len(b), end=' = '), print(len(list(product(a, b))))
print(f'\nДекартово произведение a X c = ')
print(list(product(a, c))), print(len(list(product(a, c))))
print(f'\nДекартово произведение b X c = ')
print(list(product(b, c))), print(len(list(product(b, c))))
print(f'\nДекартово произведение a X b X c = ')
print(list(product(a, b, c)))
print(len(a), end=' * '), print(len(b), end=' * '),  print(len(c), end=' = '), print(len(list(product(a, b, c))))
# Out:
# Декартово произведение a X b =
# [('семь', 2), ('семь', 4), ('семь', 6), ('семь', 8), ('семь', 'два'), ('семь', 12), ('семь', 'один'), (2, 2), (2, 4), (2, 6), (2, 8), (2, 'два'), (2, 12), (2, 'один'), (5, 2), (5, 4), (5, 6), (5, 8), (5, 'два'), (5, 12), (5, 'один'), (6, 2), (6, 4), (6, 6), (6, 8), (6, 'два'), (6, 12), (6, 'один'), (7, 2), (7, 4), (7, 6), (7, 8), (7, 'два'), (7, 12), (7, 'один'), ('четыре', 2), ('четыре', 4), ('четыре', 6), ('четыре', 8), ('четыре', 'два'), ('четыре', 12), ('четыре', 'один')]
# 6 * 7 = 42
#
# Декартово произведение a X c =
# [('семь', 'триста'), ('семь', 4), ('семь', 6), ('семь', 23), ('семь', 8), ('семь', 9), (2, 'триста'), (2, 4), (2, 6), (2, 23), (2, 8), (2, 9), (5, 'триста'), (5, 4), (5, 6), (5, 23), (5, 8), (5, 9), (6, 'триста'), (6, 4), (6, 6), (6, 23), (6, 8), (6, 9), (7, 'триста'), (7, 4), (7, 6), (7, 23), (7, 8), (7, 9), ('четыре', 'триста'), ('четыре', 4), ('четыре', 6), ('четыре', 23), ('четыре', 8), ('четыре', 9)]
# 36
#
# ...
